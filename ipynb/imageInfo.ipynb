# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# %%
im = Image.open('./test/2_1.png')

#灰度图
# image_transforms = transforms.Compose([transforms.Grayscale(1)])
# image = image_transforms(im)

#转为np array
im_array = np.array(im)
print(im_array.shape)

im=Image.fromarray(im_array[:,:,1]) # numpy 转 image类
im.show()

im=Image.fromarray(im_array[:,:,0]) # numpy 转 image类
im.show()

im=Image.fromarray(im_array[:,:,2]) # numpy 转 image类

#flatten，折线图
# im_array_flat = im_array.flatten()
# plt.plot(np.sort(im_array_flat))

im.show()
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256 at 0x7F3D2C72A510>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F3D2C72AF50>
# <PIL.Image.Image image mode=L size=256x256 at 0x7F3D2C72AA10>

# %%
np.percentile(im_array, (40))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10829/3237431771.py in <module>
# ----> 1 np.percentile(im_array, (40))
#
# NameError: name 'im_array' is not defined
